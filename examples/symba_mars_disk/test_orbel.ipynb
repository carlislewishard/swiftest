# %%
# %load_ext autoreload
# %autoreload 1
# %aimport swiftestio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import swiftestio as swio

# %%
config = swio.read_swiftest_config("param.in")
# Out:
# Reading Swiftest file param.in

# %%
ds = swio.swiftest2xr(config)
# Out:
# Reading in time 6.000e+03
# Creating Dataset
#
# Adding particle info to Dataset
# Successfully converted 11 output frames.

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:      (id: 1521, time: 11)
# Coordinates:
#   * id           (id) int64 1 2 3 4 5 6 7 ... 1515 1516 1517 1518 1519 1520 1521
#   * time         (time) float64 0.0 600.0 1.2e+03 ... 4.8e+03 5.4e+03 6e+03
# Data variables:
#     px           (time, id) float64 0.0 -2.358e+06 ... 2.857e+06 2.775e+06
#     py           (time, id) float64 0.0 8.604e+06 ... -8.703e+06 -8.67e+06
#     pz           (time, id) float64 0.0 1.252e+04 ... 5.26e+04 5.588e+04
#     vx           (time, id) float64 0.0 -2.134e+03 ... 2.049e+03 2.034e+03
#     vy           (time, id) float64 0.0 -591.2 -1.533e+03 ... 645.5 698.3 711.1
#     vz           (time, id) float64 0.0 -1.465 -0.1413 ... 4.414 5.343 2.951
#     a            (time, id) float64 0.0 9.113e+06 ... 9.176e+06 8.984e+06
#     e            (time, id) float64 0.0 0.02115 0.008838 ... 0.01143 0.0297
#     inc          (time, id) float64 0.0 0.00155 0.001431 ... 0.006276 0.006327
# ...

# %%
from swiftestpy import orbel

# %%
for i in ds.id:

# %%
p['px'].values
# Out:
# array([       0.  , -2358074.26, -8011600.07, ...,        0.  ,
#               0.  ,        0.  ])

# %%
px = p['px'].values
py = p['py'].values
pz = p['pz'].values
vx = p['vx'].values
vy = p['vy'].values
vz = p['vz'].values
mu = p['mu'].values

# %%
mu
# Out:
# array([8.56777324e+13, 4.28388663e+13, 4.28388662e+13, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
a = []
e = []
inc = []
capom = []
omega = []
capm=[]
elem = []
for i in range(mu.size):
    elem = orbel.xv2el(mu[i], px[i], py[i], pz[i], vx[i], vy[i], vz[i])
    a.append(elem[0])
    e.append(elem[1])
    inc.append(elem[2])
    capom.append(elem[3])
    omega.append(elem[4])
    capm.append(elem[5])

# %%
e
# Out:
# [0.0,
#  0.02115087630865617,
#  0.0088377100232386,
#  0.00992666177910355,
#  0.013844622579318733,
#  0.020840736362315204,
#  0.012830123436694426,
#  0.018220870899174804,
#  0.009291057214557124,
#  0.019750729134524993,
#  0.015469896951127715,
#  0.01077071404825877,
#  0.02328095741223282,
#  0.02580719900434512,
#  0.030920336538679365,
#  0.0025607106556491395,
#  0.014180584271000201,
#  0.008173492002503134,
#  0.005302576341903984,
#  0.0056649917265984544,
#  0.019511162666869163,
#  0.005774936024614055,
#  0.010587603584543697,
#  0.013305254776467731,
#  0.022869804616226497,
#  0.03874351169932835,
#  0.031362877391516365,
#  0.005580464703669635,
#  0.011053307991341622,
#  0.0026660183745185672,
#  0.011166329628689482,
#  0.010060720417353715,
#  0.02439011688970079,
#  0.010135181911721981,
#  0.012025806592680884,
#  0.011331090164378294,
#  0.0036479273971442064,
#  0.012946135835890858,
#  0.028766605290775106,
#  0.014313118572240966,
# ...
